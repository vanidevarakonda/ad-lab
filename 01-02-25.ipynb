# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Shivani\Downloads\archive\Reviews.csv", nrows=500)

df.head(3)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      500 non-null    int64
#  1   ProductId               500 non-null    object
#  2   UserId                  500 non-null    object
#  3   ProfileName             500 non-null    object
#  4   HelpfulnessNumerator    500 non-null    int64
#  5   HelpfulnessDenominator  500 non-null    int64
#  6   Score                   500 non-null    int64
#  7   Time                    500 non-null    int64
#  8   Summary                 500 non-null    object
#  9   Text                    500 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 39.2+ KB

# %%
df.Summary.head()
# Out:
# 0    Good Quality Dog Food
# 1        Not as Advertised
# 2    "Delight" says it all
# 3           Cough Medicine
# 4              Great taffy
# Name: Summary, dtype: object

# %%
df.Text.head()
# Out:
# 0    I have bought several of the Vitality canned d...
# 1    Product arrived labeled as Jumbo Salted Peanut...
# 2    This is a confection that has been around a fe...
# 3    If you are looking for the secret ingredient i...
# 4    Great taffy at a great price.  There was a wid...
# Name: Text, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 5
#       3 from nltk.corpus import stopwords
#       4 from textblob import Word
# ----> 5 from spellchecker import SpellChecker  # Faster spelling correction
#       7 # Download necessary NLTK resources
#       8 nltk.download('stopwords')
#
# ModuleNotFoundError: No module named 'spellchecker'

# %%
from nltk.corpus import stopwords
from textblob import TextBlob
from textblob import Word  


df['Text'] = df['Text'].apply(lambda x: " ".join(x.lower() for x in x.split())) 
df['Text'] = df['Text'].str.replace('[^\w\s]', '') 


stop = stopwords.words('english') 
df['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop)) 


df['Text'] = df['Text'].apply(lambda x: str(TextBlob(x).correct())) 


df['Text'] = df['Text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()])) 

df.Text.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      10 stop = stopwords.words('english')
#      11 df['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# ---> 14 df['Text'] = df['Text'].apply(lambda x: str(TextBlob(x).correct()))
#      17 df['Text'] = df['Text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
#      19 df.Text.head()
#
# File ~\.ms-ad\Lib\site-packages\pandas\core\series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\.ms-ad\Lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~\.ms-ad\Lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\.ms-ad\Lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[6], line 14, in <lambda>(x)
#      10 stop = stopwords.words('english')
#      11 df['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# ---> 14 df['Text'] = df['Text'].apply(lambda x: str(TextBlob(x).correct()))
#      17 df['Text'] = df['Text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
#      19 df.Text.head()
#
# File ~\.ms-ad\Lib\site-packages\textblob\blob.py:555, in BaseBlob.correct(self)
#     553 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
#     554 corrected = (Word(w).correct() for w in tokens)
# --> 555 ret = "".join(corrected)
#     556 return self.__class__(ret)
#
# File ~\.ms-ad\Lib\site-packages\textblob\blob.py:554, in <genexpr>(.0)
#     552 # regex matches: word or punctuation or whitespace
#     553 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
# --> 554 corrected = (Word(w).correct() for w in tokens)
#     555 ret = "".join(corrected)
#     556 return self.__class__(ret)
#
# File ~\.ms-ad\Lib\site-packages\textblob\blob.py:115, in Word.correct(self)
#     109 def correct(self):
#     110     """Correct the spelling of the word. Returns the word with the highest
#     111     confidence using the spelling corrector.
#     112
#     113     .. versionadded:: 0.6.0
#     114     """
# --> 115     return Word(self.spellcheck()[0][0])
#
# File ~\.ms-ad\Lib\site-packages\textblob\blob.py:107, in Word.spellcheck(self)
#      98 def spellcheck(self):
#      99     """Return a list of (word, confidence) tuples of spelling corrections.
#     100
#     101     Based on: Peter Norvig, "How to Write a Spelling Corrector"
#    (...)
#     105     .. versionadded:: 0.6.0
#     106     """
# --> 107     return suggest(self.string)
#
# File ~\.ms-ad\Lib\site-packages\textblob\en\__init__.py:118, in suggest(w)
#     116 def suggest(w):
#     117     """Returns a list of (word, confidence)-tuples of spelling corrections."""
# --> 118     return spelling.suggest(w)
#
# File ~\.ms-ad\Lib\site-packages\textblob\_text.py:1692, in Spelling.suggest(self, w)
#    1687 if w.replace(".", "").isdigit():
#    1688     return [(w, 1.0)]  # 1.5
#    1689 candidates = (
#    1690     self._known([w])
#    1691     or self._known(self._edit1(w))
# -> 1692     or self._known(self._edit2(w))
#    1693     or [w]
#    1694 )
#    1695 candidates = [(self.get(c, 0.0), c) for c in candidates]
#    1696 s = float(sum(p for p, word in candidates) or 1)
#
# File ~\.ms-ad\Lib\site-packages\textblob\_text.py:1667, in Spelling._edit2(self, w)
#    1664 """Returns a set of words with edit distance 2 from the given word"""
#    1665 # Of all spelling errors, 99% is covered by edit distance 2.
#    1666 # Only keep candidates that are actually known words (20% speedup).
# -> 1667 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# File ~\.ms-ad\Lib\site-packages\textblob\_text.py:1667, in <genexpr>(.0)
#    1664 """Returns a set of words with edit distance 2 from the given word"""
#    1665 # Of all spelling errors, 99% is covered by edit distance 2.
#    1666 # Only keep candidates that are actually known words (20% speedup).
# -> 1667 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# File ~\.ms-ad\Lib\site-packages\textblob\_text.py:103, in lazydict.__contains__(self, *args)
#     100 def __iter__(self):
#     101     return self._lazy("__iter__")
# --> 103 def __contains__(self, *args):
#     104     return self._lazy("__contains__", *args)
#     106 def __getitem__(self, *args):
#
# KeyboardInterrupt:

# %%
reviews = df
reviews.dropna(inplace=True)

reviews.Score.hist(bins=5,grid=False)
plt.show()
print(reviews.groupby('Score').count().Id)
# Out:
# Score
# 1     36
# 2     18
# 3     37
# 4     70
# 5    339
# Name: Id, dtype: int64

# %%
score_1 = reviews[reviews['Score'] == 1].sample(n=18)
score_2 = reviews[reviews['Score'] == 2].sample(n=18)
score_3 = reviews[reviews['Score'] == 3].sample(n=18)
score_4 = reviews[reviews['Score'] == 4].sample(n=18)
score_5 = reviews[reviews['Score'] == 5].sample(n=18)

# %%
reviews_sample = pd.concat([score_1,score_2,score_3,score_4,score_5],axis=0)
reviews_sample.reset_index(drop=True,inplace=True)

print(reviews_sample.groupby('Score').count().Id)
# Out:
# Score
# 1    18
# 2    18
# 3    18
# 4    18
# 5    18
# Name: Id, dtype: int64

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\shivani\.ms-ad\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\shivani\.ms-ad\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\shivani\.ms-ad\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\shivani\.ms-ad\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shivani\.ms-ad\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

reviews_str = " ".join(reviews_sample["Summary"].to_numpy())

wordcloud = WordCloud(background_color='white').generate(reviews_str)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.show()
