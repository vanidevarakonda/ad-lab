# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Shivani\Downloads\archive\Reviews.csv", nrows=500)

df.head(3)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      500 non-null    int64
#  1   ProductId               500 non-null    object
#  2   UserId                  500 non-null    object
#  3   ProfileName             500 non-null    object
#  4   HelpfulnessNumerator    500 non-null    int64
#  5   HelpfulnessDenominator  500 non-null    int64
#  6   Score                   500 non-null    int64
#  7   Time                    500 non-null    int64
#  8   Summary                 500 non-null    object
#  9   Text                    500 non-null    object
# dtypes: int64(5), object(5)
# memory usage: 39.2+ KB

# %%
df.Summary.head()
# Out:
# 0    Good Quality Dog Food
# 1        Not as Advertised
# 2    "Delight" says it all
# 3           Cough Medicine
# 4              Great taffy
# Name: Summary, dtype: object

# %%
df.Text.head()
# Out:
# 0    I have bought several of the Vitality canned d...
# 1    Product arrived labeled as Jumbo Salted Peanut...
# 2    This is a confection that has been around a fe...
# 3    If you are looking for the secret ingredient i...
# 4    Great taffy at a great price.  There was a wid...
# Name: Text, dtype: object

# %%
from nltk.corpus import stopwords
from textblob import TextBlob
from textblob import Word  


df['Text'] = df['Text'].apply(lambda x: " ".join(x.lower() for x in x.split())) 
df['Text'] = df['Text'].str.replace('[^\w\s]', '') 


stop = stopwords.words('english') 
df['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop)) 


df['Text'] = df['Text'].apply(lambda x: str(TextBlob(x).correct()))



df['Text'] = df['Text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()])) 

df.Text.head()

# %%
reviews = df
reviews.dropna(inplace=True)

reviews.Score.hist(bins=5,grid=False)
plt.show()
print(reviews.groupby('Score').count().Id)
# Out:
# Score
# 1     36
# 2     18
# 3     37
# 4     70
# 5    339
# Name: Id, dtype: int64

# %%
score_1 = reviews[reviews['Score'] == 1].sample(n=18)
score_2 = reviews[reviews['Score'] == 2].sample(n=18)
score_3 = reviews[reviews['Score'] == 3].sample(n=18)
score_4 = reviews[reviews['Score'] == 4].sample(n=18)
score_5 = reviews[reviews['Score'] == 5].sample(n=18)

# %%
reviews_sample = pd.concat([score_1,score_2,score_3,score_4,score_5],axis=0)
reviews_sample.reset_index(drop=True,inplace=True)

print(reviews_sample.groupby('Score').count().Id)
# Out:
# Score
# 1    18
# 2    18
# 3    18
# 4    18
# 5    18
# Name: Id, dtype: int64

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\shivani\.ms-ad\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\shivani\.ms-ad\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\shivani\.ms-ad\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\shivani\.ms-ad\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shivani\.ms-ad\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shivani\.ms-ad\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

reviews_str = " ".join(reviews_sample["Summary"].to_numpy())

wordcloud = WordCloud(background_color='white').generate(reviews_str)
plt.figure(figsize=(10,10))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
negative_reviews = reviews_sample[reviews_sample['Score'].isin([1,2])]
positive_reviews = reviews_sample[reviews_sample['Score'].isin([4,5])]

negative_reviews_str = negative_reviews.Summary.str.cat(sep=" ")
positive_reviews_str = positive_reviews.Summary.str.cat(sep=" ")

# %%
wordcloud_negative = WordCloud(background_color='white').generate(negative_reviews_str)
wordcloud_positive = WordCloud(background_color='white').generate(positive_reviews_str)

fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(211)
ax1.imshow(wordcloud_negative,interpolation='bilinear')
ax1.set_title('Reviews with Negstive Score',fontsize=20)
              
ax2 = fig.add_subplot(212)
ax2.imshow(wordcloud_positive,interpolation='bilinear')
ax2.axis("off")
ax2.set_title('Reviews with Positive Scores',fontsize=20)
plt.show()

# %%
import seaborn as sns
from vaderSent imnet.vaderSebtiment import SentimentIntensityAnalyzer
plt.style.use('fivethirtyeight')
cp = sns.color_palette()

analyzer = SentimentIntensityAnalyzer()
emptyline=[]
for row in df['Text']:
    vs=analyzer.polarity_scores(row)
    emptyline.append(vs)
# Out:
#   Cell In[23], line 2
#     from vaderSent imnet.vaderSebtiment import SentimentIntensityAnalyzer
#                    ^
# SyntaxError: invalid syntax
